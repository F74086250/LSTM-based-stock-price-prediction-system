# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests

# %%
TRAIN = '開盤價'
TARGET = '收盤價'

# %%
url = "https://api.finmindtrade.com/api/v4/login"
account = {
    "user_id": "F74086250",
    "password": "Aeiou95048",
}
token = requests.post(url, data=account).json()['token']

url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockPrice",
    "data_id": "2330",
    "start_date": "2020-01-01",
    "end_date": "2021-06-03",
    "token":token
}
data = pd.DataFrame(requests.get(url, params=parameter).json()["data"])
data['average'] = data["Trading_money"]/data["Trading_Volume"]
data
# Out:
#            date stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0    2020-01-02     2330        33282120    11224165450  332.5  339.0  332.5
# 1    2020-01-03     2330        42023268    14295651580  344.0  345.0  335.5
# 2    2020-01-06     2330        45677057    15210531318  333.0  334.5  332.0
# 3    2020-01-07     2330        51746181    17053282011  332.5  333.0  326.5
# 4    2020-01-08     2330        37913748    12484410088  325.0  333.0  325.0
# ..          ...      ...             ...            ...    ...    ...    ...
# 338  2021-05-28     2330        30720737    18082265480  587.0  592.0  582.0
# 339  2021-05-31     2330        31557426    18751716595  595.0  597.0  590.0
# 340  2021-06-01     2330        18405285    10985893229  598.0  599.0  595.0
# 341  2021-06-02     2330        22416789    13362065937  600.0  600.0  593.0
# 342  2021-06-03     2330        31703679    18939839664  600.0  600.0  596.0
#
#      close  spread  Trading_turnover     average
# 0    339.0     8.0             17160  337.243104
# 1    339.5     0.5             20545  340.184195
# 2    332.0    -7.5             22944  333.001562
# 3    329.5    -2.5             22362  329.556340
# 4    329.5     0.0             18228  329.284514
# ..     ...     ...               ...         ...
# 338  590.0     8.0             31581  588.601292
# 339  597.0     7.0             29798  594.209318
# 340  598.0     1.0             20318  596.887972
# 341  595.0    -3.0             25170  596.074038
# 342  596.0     1.0             20749  597.401950
#
# [343 rows x 11 columns]

# %%
#取得個股的融資卷增減量(張) (data2)
parameter = {
    "dataset": "TaiwanStockMarginPurchaseShortSale",
    "data_id": "2603",
    "start_date": "2020-01-01",
    "token":token, # 參考登入，獲取金鑰
}
data2 = requests.get(url, params=parameter).json()
data2 = pd.DataFrame(data2['data'])
data2=data2[["MarginPurchaseTodayBalance","MarginPurchaseYesterdayBalance","ShortSaleTodayBalance","ShortSaleYesterdayBalance"]]
data2["MarginPurchaseVariation"]=data2["MarginPurchaseTodayBalance"]-data2["MarginPurchaseYesterdayBalance"]
data2["ShortSaleVariation"]=data2["ShortSaleTodayBalance"]-data2["ShortSaleYesterdayBalance"]
data2

data2=data2.drop(343,axis=0)
data2
# Out:
#      MarginPurchaseTodayBalance  MarginPurchaseYesterdayBalance  \
# 0                         37284                           37295
# 1                         37288                           37284
# 2                         39840                           37288
# 3                         39195                           39840
# 4                         39501                           39195
# ..                          ...                             ...
# 338                      319856                          278896
# 339                      315497                          319856
# 340                      352092                          315497
# 341                      328326                          352092
# 342                      338216                          328326
#
#      ShortSaleTodayBalance  ShortSaleYesterdayBalance  \
# 0                       37                         31
# 1                      120                         37
# 2                      158                        120
# 3                      116                        158
# 4                       84                        116
# ..                     ...                        ...
# 338                  30160                      26768
# 339                  30408                      30160
# 340                  33895                      30408
# 341                  31775                      33895
# 342                  33326                      31775
#
#      MarginPurchaseVariation  ShortSaleVariation
# 0                        -11                   6
# 1                          4                  83
# 2                       2552                  38
# 3                       -645                 -42
# 4                        306                 -32
# ..                       ...                 ...
# 338                    40960                3392
# 339                    -4359                 248
# 340                    36595                3487
# 341                   -23766               -2120
# 342                     9890                1551
#
# [343 rows x 6 columns]

# %%
#取得個股的股利,本益比,淨值比(data3)
parameter = {
    "dataset": "TaiwanStockPER",
    "data_id": "2330",
    "start_date": "2020-01-01",
    "token":token, # 參考登入，獲取金鑰
}
data3 = requests.get(url, params=parameter).json()
data3 = pd.DataFrame(data3['data'])
data3=data3.drop(["date","stock_id"],axis=1)

data3=data3.drop(343,axis=0)
data3
# Out:
#      dividend_yield    PER   PBR
# 0              2.36  26.69  5.54
# 1              2.36  26.73  5.55
# 2              2.41  26.14  5.42
# 3              2.43  25.94  5.38
# 4              2.43  25.94  5.38
# ..              ...    ...   ...
# 338            1.69  28.30  7.89
# 339            1.68  28.63  7.98
# 340            1.67  28.68  8.00
# 341            1.68  28.54  7.96
# 342            1.68  28.59  7.97
#
# [343 rows x 3 columns]

# %%
#取得大盤的融資餘額(百萬)以及融卷張數 (data4)
parameter = {
    "dataset": "TaiwanStockTotalMarginPurchaseShortSale",
    "start_date": "2020-01-01",
    "token":token, # 參考登入，獲取金鑰
}
data4 = requests.get(url, params=parameter).json()
data4 = pd.DataFrame(data4['data'])[["TodayBalance","name"]]
data4=data4[~data4['name'].isin(["MarginPurchase"])]
MarginPurchaseMoney=data4[data4["name"]=="MarginPurchaseMoney"].drop(columns="name")
MarginPurchaseMoney.rename(columns={"TodayBalance":"MarginPurchaseMoney"})
MarginPurchaseMoney=MarginPurchaseMoney["TodayBalance"]/10000000
MarginPurchaseMoney=MarginPurchaseMoney.to_frame().rename(columns={"TodayBalance":"MarginPurchaseMoney"})
ShortSale=data4[data4["name"]=="ShortSale"].drop(columns="name")
ShortSale=ShortSale.rename(columns={"TodayBalance":"Shortsale"})
mod=list(range(len(data)))
MarginPurchaseMoney=MarginPurchaseMoney.set_axis(mod)
ShortSale=ShortSale.set_axis(mod)
data4=MarginPurchaseMoney.join(ShortSale)
data4

data4=data4.drop(343,axis=0)
data4
# Out:
#      MarginPurchaseMoney  Shortsale
# 0             14560.4286     654584
# 1             14461.7307     652415
# 2             14546.1073     690772
# 3             14459.4678     691277
# 4             14369.2800     662743
# ..                   ...        ...
# 338           23336.5365     556327
# 339           23404.7805     551036
# 340           24012.6099     563095
# 341           24049.8196     550856
# 342           24595.8470     559529
#
# [343 rows x 2 columns]

# %%
#大盤指數,與漲跌點數
data5 = pd.read_csv('TAIEX.csv')
data5=data5.iloc[::-1]
mod=list(range(len(data)))
data5=data5.set_axis(mod).drop(["日期","報酬指數值",'漲跌百分比'],axis=1)
data5.columns = ['大盤指數','漲跌點數']
data5
# Out:
#          大盤指數    漲跌點數
# 0    12100.48  103.34
# 1    12110.43    9.95
# 2    11953.36 -157.07
# 3    11880.32  -73.04
# 4    11817.10  -63.22
# ..        ...     ...
# 338  16870.86  269.25
# 339  17068.43  197.57
# 340  17162.38   93.95
# 341  17165.04    2.66
# 342  17246.16   81.12
#
# [343 rows x 2 columns]

# %%
#將多張dataframe合併
data=data.join(data2)
data=data.join(data3)
data=data.join(data4)
data=data.join(data5)
data
# Out:
#            date stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0    2020-01-02     2330        33282120    11224165450  332.5  339.0  332.5
# 1    2020-01-03     2330        42023268    14295651580  344.0  345.0  335.5
# 2    2020-01-06     2330        45677057    15210531318  333.0  334.5  332.0
# 3    2020-01-07     2330        51746181    17053282011  332.5  333.0  326.5
# 4    2020-01-08     2330        37913748    12484410088  325.0  333.0  325.0
# ..          ...      ...             ...            ...    ...    ...    ...
# 338  2021-05-28     2330        30720737    18082265480  587.0  592.0  582.0
# 339  2021-05-31     2330        31557426    18751716595  595.0  597.0  590.0
# 340  2021-06-01     2330        18405285    10985893229  598.0  599.0  595.0
# 341  2021-06-02     2330        22416789    13362065937  600.0  600.0  593.0
# 342  2021-06-03     2330        31703679    18939839664  600.0  600.0  596.0
#
#      close  spread  Trading_turnover  ...  ShortSaleYesterdayBalance  \
# 0    339.0     8.0             17160  ...                         31
# 1    339.5     0.5             20545  ...                         37
# 2    332.0    -7.5             22944  ...                        120
# 3    329.5    -2.5             22362  ...                        158
# 4    329.5     0.0             18228  ...                        116
# ..     ...     ...               ...  ...                        ...
# 338  590.0     8.0             31581  ...                      26768
# 339  597.0     7.0             29798  ...                      30160
# 340  598.0     1.0             20318  ...                      30408
# 341  595.0    -3.0             25170  ...                      33895
# 342  596.0     1.0             20749  ...                      31775
#
#      MarginPurchaseVariation  ShortSaleVariation  dividend_yield    PER   PBR  \
# 0                        -11                   6            2.36  26.69  5.54
# 1                          4                  83            2.36  26.73  5.55
# 2                       2552                  38            2.41  26.14  5.42
# 3                       -645                 -42            2.43  25.94  5.38
# 4                        306                 -32            2.43  25.94  5.38
# ..                       ...                 ...             ...    ...   ...
# 338                    40960                3392            1.69  28.30  7.89
# 339                    -4359                 248            1.68  28.63  7.98
# 340                    36595                3487            1.67  28.68  8.00
# 341                   -23766               -2120            1.68  28.54  7.96
# 342                     9890                1551            1.68  28.59  7.97
#
#      MarginPurchaseMoney  Shortsale      大盤指數    漲跌點數
# 0             14560.4286     654584  12100.48  103.34
# 1             14461.7307     652415  12110.43    9.95
# 2             14546.1073     690772  11953.36 -157.07
# 3             14459.4678     691277  11880.32  -73.04
# 4             14369.2800     662743  11817.10  -63.22
# ..                   ...        ...       ...     ...
# 338           23336.5365     556327  16870.86  269.25
# 339           23404.7805     551036  17068.43  197.57
# 340           24012.6099     563095  17162.38   93.95
# 341           24049.8196     550856  17165.04    2.66
# 342           24595.8470     559529  17246.16   81.12
#
# [343 rows x 24 columns]

# %%
data.columns=["日期","股票編號","當日成交量","當日成交金額","開盤價","最高價","最低價","收盤價","買賣價差","周轉率",'平均成交價',"當日融資","昨日融資","當日融卷","昨日融卷","融資變化","融券變化","殖利率","本益比","股價淨值比","大盤融資餘額(百萬)","大盤融卷量","大盤指數","大盤漲跌"]

# %%
for column in data:
    print(column)
data
# Out:
# 日期
# 股票編號
# 當日成交量
# 當日成交金額
# 開盤價
# 最高價
# 最低價
# 收盤價
# 買賣價差
# 周轉率
# 平均成交價
# 當日融資
# 昨日融資
# 當日融卷
# 昨日融卷
# 融資變化
# 融券變化
# 殖利率
# 本益比
# 股價淨值比
# 大盤融資餘額(百萬)
# 大盤融卷量
# 大盤指數
# 大盤漲跌
#              日期  股票編號     當日成交量       當日成交金額    開盤價    最高價    最低價    收盤價  \
# 0    2020-01-02  2330  33282120  11224165450  332.5  339.0  332.5  339.0
# 1    2020-01-03  2330  42023268  14295651580  344.0  345.0  335.5  339.5
# 2    2020-01-06  2330  45677057  15210531318  333.0  334.5  332.0  332.0
# 3    2020-01-07  2330  51746181  17053282011  332.5  333.0  326.5  329.5
# 4    2020-01-08  2330  37913748  12484410088  325.0  333.0  325.0  329.5
# ..          ...   ...       ...          ...    ...    ...    ...    ...
# 338  2021-05-28  2330  30720737  18082265480  587.0  592.0  582.0  590.0
# 339  2021-05-31  2330  31557426  18751716595  595.0  597.0  590.0  597.0
# 340  2021-06-01  2330  18405285  10985893229  598.0  599.0  595.0  598.0
# 341  2021-06-02  2330  22416789  13362065937  600.0  600.0  593.0  595.0
# 342  2021-06-03  2330  31703679  18939839664  600.0  600.0  596.0  596.0
#
#      買賣價差    周轉率  ...   昨日融卷   融資變化  融券變化   殖利率    本益比  股價淨值比  大盤融資餘額(百萬)  \
# 0     8.0  17160  ...     31    -11     6  2.36  26.69   5.54  14560.4286
# 1     0.5  20545  ...     37      4    83  2.36  26.73   5.55  14461.7307
# 2    -7.5  22944  ...    120   2552    38  2.41  26.14   5.42  14546.1073
# 3    -2.5  22362  ...    158   -645   -42  2.43  25.94   5.38  14459.4678
# 4     0.0  18228  ...    116    306   -32  2.43  25.94   5.38  14369.2800
# ..    ...    ...  ...    ...    ...   ...   ...    ...    ...         ...
# 338   8.0  31581  ...  26768  40960  3392  1.69  28.30   7.89  23336.5365
# 339   7.0  29798  ...  30160  -4359   248  1.68  28.63   7.98  23404.7805
# 340   1.0  20318  ...  30408  36595  3487  1.67  28.68   8.00  24012.6099
# 341  -3.0  25170  ...  33895 -23766 -2120  1.68  28.54   7.96  24049.8196
# 342   1.0  20749  ...  31775   9890  1551  1.68  28.59   7.97  24595.8470
#
#       大盤融卷量      大盤指數    大盤漲跌
# 0    654584  12100.48  103.34
# 1    652415  12110.43    9.95
# 2    690772  11953.36 -157.07
# 3    691277  11880.32  -73.04
# 4    662743  11817.10  -63.22
# ..      ...       ...     ...
# 338  556327  16870.86  269.25
# 339  551036  17068.43  197.57
# 340  563095  17162.38   93.95
# 341  550856  17165.04    2.66
# 342  559529  17246.16   81.12
#
# [343 rows x 24 columns]

# %%
data.head()
# Out:
#            日期  股票編號     當日成交量       當日成交金額    開盤價    最高價    最低價    收盤價  買賣價差  \
# 0  2020-01-02  2330  33282120  11224165450  332.5  339.0  332.5  339.0   8.0
# 1  2020-01-03  2330  42023268  14295651580  344.0  345.0  335.5  339.5   0.5
# 2  2020-01-06  2330  45677057  15210531318  333.0  334.5  332.0  332.0  -7.5
# 3  2020-01-07  2330  51746181  17053282011  332.5  333.0  326.5  329.5  -2.5
# 4  2020-01-08  2330  37913748  12484410088  325.0  333.0  325.0  329.5   0.0
#
#      周轉率  ...  昨日融卷  融資變化  融券變化   殖利率    本益比  股價淨值比  大盤融資餘額(百萬)   大盤融卷量  \
# 0  17160  ...    31   -11     6  2.36  26.69   5.54  14560.4286  654584
# 1  20545  ...    37     4    83  2.36  26.73   5.55  14461.7307  652415
# 2  22944  ...   120  2552    38  2.41  26.14   5.42  14546.1073  690772
# 3  22362  ...   158  -645   -42  2.43  25.94   5.38  14459.4678  691277
# 4  18228  ...   116   306   -32  2.43  25.94   5.38  14369.2800  662743
#
#        大盤指數    大盤漲跌
# 0  12100.48  103.34
# 1  12110.43    9.95
# 2  11953.36 -157.07
# 3  11880.32  -73.04
# 4  11817.10  -63.22
#
# [5 rows x 24 columns]

# %%
fig=plt.figure(figsize=(20,8))
plt.xticks(rotation = 90)  
ax1 = fig.add_subplot(111)
ax1.plot(data.收盤價,color='red',label='收盤價')
ax1.plot(data.開盤價,color='green',label='開盤價')
plt.legend()
# twin 為共享x軸
ax2= ax1.twinx()
plt.bar(data.日期,data.當日成交量.astype('int')//1000)
ax3 = ax1.twinx()
plt.savefig('2330_year.png')
# Out:
# <ipython-input-66-ef47dcf5ec4c>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax1 = fig.add_subplot(111)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 25910 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 30436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38283 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 25910 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 30436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 38283 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#切分Test集
test = data[data.日期>'2021-01-01']
train = data[data.日期<='2021-01-01']
#只要open high
train_set_x = train[TRAIN]
train_set_y = train[TARGET]

# %%
from sklearn.preprocessing import MinMaxScaler 
sc = MinMaxScaler(feature_range = (0, 1))
#需將資料做reshape的動作，使其shape為(資料長度,1) 
train_set_x= train_set_x.values.reshape(-1,1)
training_set_scaled_x = sc.fit_transform(train_set_x)
train_set_y= train_set_y.values.reshape(-1,1)
training_set_scaled_y = sc.fit_transform(train_set_y)

# %%
training_set_scaled_x
# Out:
# array([[0.29379562],
#        [0.33576642],
#        [0.29562044],
#        [0.29379562],
#        [0.26642336],
#        [0.30291971],
#        [0.3229927 ],
#        [0.32846715],
#        [0.34124088],
#        [0.33941606],
#        [0.28467153],
#        [0.29927007],
#        [0.29927007],
#        [0.27007299],
#        [0.25912409],
#        [0.22992701],
#        [0.68430657],
#        [0.63868613],
#        [0.64233577],
#        [0.64233577],
#        [0.63138686],
#        [0.65875912],
#        [0.66970803],
#        [0.67153285],
#        [0.6879562 ],
#        [0.75912409],
#        [0.73357664],
#        [0.71167883],
#        [0.69890511],
#        [0.68613139],
#        [0.67153285],
#        [0.63321168],
#        [0.63868613],
#        [0.63868613],
#        [0.65875912],
#        [0.65145985],
#        [0.67883212],
#        [0.69160584],
#        [0.66788321],
#        [0.72262774],
#        [0.75182482],
#        [0.77737226],
#        [0.76094891],
#        [0.74452555],
#        [0.72627737],
#        [0.73357664],
#        [0.74270073],
#        [0.73540146],
#        [0.72262774],
#        [0.75182482],
#        [0.74087591],
#        [0.71350365],
#        [0.70437956],
#        [0.67335766],
#        [0.67518248],
#        [0.66058394],
#        [0.68430657],
#        [0.70255474],
#        [0.72810219],
#        [0.74087591],
#        [0.75182482],
#        [0.72992701],
#        [0.71715328],
#        [0.77007299],
#        [0.75547445],
#        [0.79562044],
#        [0.91240876],
#        [0.86861314],
#        [0.90145985],
#        [0.8540146 ],
#        [0.8850365 ],
#        [0.90328467],
#        [0.88686131],
#        [0.8649635 ],
#        [0.85948905],
#        [0.87956204],
#        [0.86678832],
#        [0.90328467],
#        [0.90328467],
#        [0.89963504],
#        [0.94890511],
#        [0.95620438],
#        [0.98175182],
#        [0.94525547],
#        [0.96715328],
#        [0.94890511],
#        [0.93065693],
#        [0.9379562 ],
#        [0.95985401],
#        [0.93430657],
#        [0.94890511],
#        [0.94890511],
#        [0.93430657],
#        [0.94525547],
#        [0.95620438],
#        [0.94890511],
#        [0.95985401],
#        [0.96350365],
#        [1.        ]])

# %%
len(train_set_x),len(train_set_y),len(training_set_scaled_x),len(training_set_scaled_y)
# Out:
# (245, 245, 245, 245)

# %%
X_train = [] 
y_train = []
for i in range(10,len(train_set_x)):
    X_train.append(training_set_scaled_x[i-10:i, 0]) 
    y_train.append(training_set_scaled_y[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train) 
X_train = np.reshape(X_train, 
                         (X_train.shape[0], X_train.shape[1], 1))
X_train,y_train
# Out:
# (array([[[0.29379562],
#          [0.33576642],
#          [0.29562044],
#          ...,
#          [0.32846715],
#          [0.34124088],
#          [0.33941606]],
#
#         [[0.33576642],
#          [0.29562044],
#          [0.29379562],
#          ...,
#          [0.34124088],
#          [0.33941606],
#          [0.28467153]],
#
#         [[0.29562044],
#          [0.29379562],
#          [0.26642336],
#          ...,
#          [0.33941606],
#          [0.28467153],
#          [0.29927007]],
#
#         ...,
#
#         [[0.93065693],
#          [0.9379562 ],
#          [0.95985401],
#          ...,
#          [0.94525547],
#          [0.95620438],
#          [0.94890511]],
#
#         [[0.9379562 ],
#          [0.95985401],
#          [0.93430657],
#          ...,
#          [0.95620438],
#          [0.94890511],
#          [0.95985401]],
#
#         [[0.95985401],
#          [0.93430657],
#          [0.94890511],
#          ...,
#          [0.94890511],
#          [0.95985401],
#          [0.96350365]]]),
#         0.75886525, 0.83687943, 0.84219858, 0.88297872, 0.85815603,
#         0.85106383, 0.88120567, 0.86524823, 0.84751773, 0.85460993,
#         0.85460993, 0.82446809, 0.85815603, 0.89007092, 0.88297872,
#         0.90425532, 0.94326241, 0.9787234 , 0.96453901, 0.93617021,
#         0.95035461, 0.92198582, 0.90780142, 0.93617021, 0.92198582,
#         0.92907801, 0.95035461, 0.92553191, 0.92553191, 0.92907801,
#         0.93262411, 0.94680851, 0.94680851, 0.9822695 , 1.        ]))

# %%
X_train[0],y_train[0]
# Out:
# (array([[0.29379562],
#         [0.33576642],
#         [0.29562044],
#         [0.29379562],
#         [0.26642336],
#         [0.30291971],
#         [0.3229927 ],
#         [0.32846715],
#         [0.34124088],
#         [0.33941606]]),
#  0.30673758865248235)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout,BatchNormalization

# %%
keras.backend.clear_session()
regressor = Sequential()
regressor.add(LSTM(units = 100, input_shape = (X_train.shape[1], 1)))
regressor.add(Dense(units = 1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = regressor.fit(X_train, y_train, epochs = 150, batch_size = 16)
plt.title('train_loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.plot( history.history["loss"])
# Out:
# Epoch 1/150
# 15/15 [==============================] - 2s 10ms/step - loss: 0.1469
# Epoch 2/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0133
# Epoch 3/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0042
# Epoch 4/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 5/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0024
# Epoch 6/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 7/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0027
# Epoch 8/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 9/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 10/150
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 11/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 12/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 13/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 14/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 15/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 16/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 17/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 18/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 19/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 20/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 21/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 22/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 23/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 24/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 25/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 26/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 27/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 28/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 29/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 30/150
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 31/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 32/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 33/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 34/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 35/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 36/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 37/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 38/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 39/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 40/150
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 41/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 42/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 43/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 44/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 45/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 46/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 47/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 48/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 49/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 50/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 51/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 52/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 53/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 54/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 55/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 56/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 57/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 58/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 59/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 60/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 61/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 62/150
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 63/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 64/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 65/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 66/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 67/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 68/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 69/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 70/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 71/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 72/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 73/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 74/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 75/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 76/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 77/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 78/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 79/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 80/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 81/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 82/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 83/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 84/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 85/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 86/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 87/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 88/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 89/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 90/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 91/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 92/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 93/150
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 94/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 95/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 96/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 97/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 98/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 99/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 100/150
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0012
# Epoch 101/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 102/150
# 15/15 [==============================] - 0s 13ms/step - loss: 9.6057e-04
# Epoch 103/150
# 15/15 [==============================] - 0s 10ms/step - loss: 9.7971e-04
# Epoch 104/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 105/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 106/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 107/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 108/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 109/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 110/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 111/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 112/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 113/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 114/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 115/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 116/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 117/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 118/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 119/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 120/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 121/150
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 122/150
# 15/15 [==============================] - 0s 11ms/step - loss: 9.3866e-04
# Epoch 123/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 124/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 125/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 126/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 127/150
# 15/15 [==============================] - 0s 11ms/step - loss: 9.7036e-04
# Epoch 128/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 129/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 130/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 131/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 132/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 133/150
# 15/15 [==============================] - 0s 5ms/step - loss: 9.3729e-04
# Epoch 134/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 135/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 136/150
# 15/15 [==============================] - 0s 5ms/step - loss: 9.3722e-04
# Epoch 137/150
# 15/15 [==============================] - 0s 6ms/step - loss: 8.9738e-04
# Epoch 138/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 139/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 140/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 141/150
# 15/15 [==============================] - 0s 5ms/step - loss: 8.6934e-04
# Epoch 142/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 143/150
# 15/15 [==============================] - 0s 5ms/step - loss: 8.1404e-04
# Epoch 144/150
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0010
# Epoch 145/150
# 15/15 [==============================] - 0s 5ms/step - loss: 9.0463e-04
# Epoch 146/150
# 15/15 [==============================] - 0s 5ms/step - loss: 7.4657e-04
# Epoch 147/150
# 15/15 [==============================] - 0s 5ms/step - loss: 9.7899e-04
# Epoch 148/150
# 15/15 [==============================] - 0s 5ms/step - loss: 9.9687e-04
# Epoch 149/150
# 15/15 [==============================] - 0s 5ms/step - loss: 9.2128e-04
# Epoch 150/150
# 15/15 [==============================] - 0s 5ms/step - loss: 8.8332e-04

# %%
dataset_total = pd.concat((train[TRAIN], test[TARGET]), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test) - 10:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(10, len(inputs)):
    X_test.append(inputs[i-10:i, 0])
#print(X_test)
X_test = np.array(X_test)
print(type(X_test))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
#使用sc的 inverse_transform將股價轉為歸一化前
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# <class 'numpy.ndarray'>

# %%
def confusion_matrix(delay,test):
    real_tendency=[]
    predicted_tendency=[]
    df_test=test
    #delay=2
    real_tendency.append('NaN')
    predicted_tendency.append('NaN')
    gap=len(data)-len(test)
    for i in range(1,len(predicted_stock_price)-delay):
        if(test['收盤價'][i+gap]-test['收盤價'][i+gap-1]>0):
            real_tendency.append(1)
        if(test['收盤價'][i+gap]-test['收盤價'][i+gap-1]==0):
            real_tendency.append(0)
        if(test['收盤價'][i+gap]-test['收盤價'][i+gap-1]<0):
            real_tendency.append(-1)
        if(predicted_stock_price[i+delay]-predicted_stock_price[i+delay-1]>0):
            predicted_tendency.append(1)
        if(predicted_stock_price[i+delay]-predicted_stock_price[i+delay-1]==0):
            predicted_tendency.append(0)
        if(predicted_stock_price[i+delay]-predicted_stock_price[i+delay-1]<0):
            predicted_tendency.append(-1)
    real_tendency,predicted_tendency
    df_test=df_test.reset_index()
    for i in range(delay):
        real_tendency.append(0)
        predicted_tendency.append(0)

    df_test['real_tendency']=real_tendency
    df_test['predicted_stock_price']=predicted_stock_price
    df_test['predicted_tendency']=predicted_tendency
    count=0
    """
    for i in range(len(df_test)):
        if(df_test['real_tendency'][i]==df_test['predicted_tendency'][i]):
            count+=1
            print(df_test['date'][i],df_test['predicted_tendency'][i])
    print(len(test),count)
    """
    tp=0
    fp=0
    fn=0
    tn=0
    for i in range(1,len(df_test)):
        if(df_test['real_tendency'][i]==df_test['predicted_tendency'][i] and df_test['predicted_tendency'][i]==1):
            tp+=1
        if(df_test['real_tendency'][i]==df_test['predicted_tendency'][i] and df_test['predicted_tendency'][i]==-1):
            tn+=1
        if(df_test['real_tendency'][i]!=df_test['predicted_tendency'][i] and df_test['predicted_tendency'][i]==1 and df_test['real_tendency'][i]==-1):
            fp+=1
        if(df_test['real_tendency'][i]!=df_test['predicted_tendency'][i] and df_test['predicted_tendency'][i]==-1 and df_test['real_tendency'][i]==1):
            fn+=1
    tp,tn,fp,fn,len(df_test)-(delay+1)
    accuracy=(tp+tn)/(len(df_test)-(delay+1))
    precision=tp/(tp+fp)
    recall=tp/(tp+fn)
    f1_score=2/((1/precision)+(1/recall))
    print('delay day=',delay,' accuracy=',round(accuracy,6),' precision=',round(precision,6),' recall=',round(recall,6),' f1_score=',round(f1_score,6))
    return ""
for i in range(10):
    confusion_matrix(i,test)
# Out:
# delay day= 0  accuracy= 0.505155  precision= 0.533333  recall= 0.521739  f1_score= 0.527473
# delay day= 1  accuracy= 0.864583  precision= 0.911111  recall= 0.911111  f1_score= 0.911111
# delay day= 2  accuracy= 0.652632  precision= 0.697674  recall= 0.666667  f1_score= 0.681818
# delay day= 3  accuracy= 0.457447  precision= 0.477273  recall= 0.477273  f1_score= 0.477273
# delay day= 4  accuracy= 0.44086  precision= 0.452381  recall= 0.44186  f1_score= 0.447059
# delay day= 5  accuracy= 0.391304  precision= 0.390244  recall= 0.380952  f1_score= 0.385542
# delay day= 6  accuracy= 0.483516  precision= 0.5  recall= 0.47619  f1_score= 0.487805
# delay day= 7  accuracy= 0.466667  precision= 0.473684  recall= 0.439024  f1_score= 0.455696
# delay day= 8  accuracy= 0.516854  precision= 0.526316  recall= 0.5  f1_score= 0.512821
# delay day= 9  accuracy= 0.579545  precision= 0.605263  recall= 0.575  f1_score= 0.589744

# %%
print('predict by',TRAIN)
plt.plot(test[TARGET].values, color = 'black', label = 'Real TSMC Stock'+' '+TARGET)
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TSMC Stock'+' '+TARGET)
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(TARGET)
plt.legend()
plt.show()
# plt.savefig('lstm_2330.png')
# Out:
# predict by 開盤價
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 25910 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 30436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 25910 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 30436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
keras.backend.clear_session()
regressor = Sequential()
regressor.add(LSTM(units = 100,return_sequences=True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 100,activation='relu'))
regressor.add(Dense(units = 1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 100)           40800
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = regressor.fit(X_train, y_train, epochs = 150, batch_size = 16)
plt.title('train_loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.plot( history.history["loss"])
# Out:
# Epoch 1/150
# 15/15 [==============================] - 6s 10ms/step - loss: 0.1794
# Epoch 2/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0165
# Epoch 3/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0084
# Epoch 4/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0045
# Epoch 5/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0033
# Epoch 6/150
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0032
# Epoch 7/150
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0033
# Epoch 8/150
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0035
# Epoch 9/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0037
# Epoch 10/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0031
# Epoch 11/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0029
# Epoch 12/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0028
# Epoch 13/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 14/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0028
# Epoch 15/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 16/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0024
# Epoch 17/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0028
# Epoch 18/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0031
# Epoch 19/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0032
# Epoch 20/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0028
# Epoch 21/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0030
# Epoch 22/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0032
# Epoch 23/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0042
# Epoch 24/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0030
# Epoch 25/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0026
# Epoch 26/150
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0025
# Epoch 27/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0027
# Epoch 28/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 29/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0022
# Epoch 30/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0025
# Epoch 31/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0029
# Epoch 32/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0026
# Epoch 33/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0030
# Epoch 34/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0027
# Epoch 35/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0026
# Epoch 36/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 37/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0025
# Epoch 38/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0022
# Epoch 39/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0025
# Epoch 40/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0027
# Epoch 41/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0023
# Epoch 42/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0020
# Epoch 43/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0019
# Epoch 44/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 45/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 46/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 47/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 48/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 49/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 50/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0021
# Epoch 51/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0021
# Epoch 52/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 53/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 54/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 55/150
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 56/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0016
# Epoch 57/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0016
# Epoch 58/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0019
# Epoch 59/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0024
# Epoch 60/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0022
# Epoch 61/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 62/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 63/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0021
# Epoch 64/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 65/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0019
# Epoch 66/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0019
# Epoch 67/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 68/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0021
# Epoch 69/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 70/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 71/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0016
# Epoch 72/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0018
# Epoch 73/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0018
# Epoch 74/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0015
# Epoch 75/150
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0018
# Epoch 76/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0015
# Epoch 77/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 78/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 79/150
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 80/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 81/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0020
# Epoch 82/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 83/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 84/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 85/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 86/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 87/150
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0019
# Epoch 88/150
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0020
# Epoch 89/150
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0022
# Epoch 90/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0021
# Epoch 91/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0015
# Epoch 92/150
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 93/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 94/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 95/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 96/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 97/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 98/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 99/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 100/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 101/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 102/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 103/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 104/150
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 105/150
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0016
# Epoch 106/150
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0014
# Epoch 107/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0016
# Epoch 108/150
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0013
# Epoch 109/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0017
# Epoch 110/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 111/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 112/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 113/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 114/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 115/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 116/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 117/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 118/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 119/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 120/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 121/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0013
# Epoch 122/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0013
# Epoch 123/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0011
# Epoch 124/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0012
# Epoch 125/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0014
# Epoch 126/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0012
# Epoch 127/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 128/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 129/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 130/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 131/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 132/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 133/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 134/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 135/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 136/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 137/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 138/150
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 139/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0012
# Epoch 140/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0011
# Epoch 141/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0013
# Epoch 142/150
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0013
# Epoch 143/150
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0011
# Epoch 144/150
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 145/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 146/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 147/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 148/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 149/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 150/150
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0014

# %%
dataset_total = pd.concat((train[TRAIN], test[TARGET]), axis = 0)
print(len(dataset_total),len(test))
inputs = dataset_total[len(dataset_total) - len(test) - 10:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
print(len(inputs))
X_test = []
for i in range(10, len(inputs)):
    X_test.append(inputs[i-10:i-1, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(len(X_test))
predicted_stock_price = regressor.predict(X_test)
#使用sc的 inverse_transform將股價轉為歸一化前
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 343 98
# 108
# 98
# WARNING:tensorflow:Model was constructed with shape (None, 10, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 10, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 9, 1).

# %%
for i in range(10):
    confusion_matrix(i,test)
# Out:
# delay day= 0  accuracy= 0.463918  precision= 0.489796  recall= 0.521739  f1_score= 0.505263
# delay day= 1  accuracy= 0.489583  precision= 0.510204  recall= 0.555556  f1_score= 0.531915
# delay day= 2  accuracy= 0.821053  precision= 0.836735  recall= 0.911111  f1_score= 0.87234
# delay day= 3  accuracy= 0.680851  precision= 0.702128  recall= 0.75  f1_score= 0.725275
# delay day= 4  accuracy= 0.526882  precision= 0.541667  recall= 0.604651  f1_score= 0.571429
# delay day= 5  accuracy= 0.478261  precision= 0.489362  recall= 0.547619  f1_score= 0.516854
# delay day= 6  accuracy= 0.428571  precision= 0.444444  recall= 0.47619  f1_score= 0.45977
# delay day= 7  accuracy= 0.477778  precision= 0.488372  recall= 0.512195  f1_score= 0.5
# delay day= 8  accuracy= 0.449438  precision= 0.452381  recall= 0.475  f1_score= 0.463415
# delay day= 9  accuracy= 0.568182  precision= 0.585366  recall= 0.6  f1_score= 0.592593

# %%
print('drop out version,predict by',TRAIN)
plt.plot(test[TARGET].values, color = 'black', label = 'Real TSMC Stock Price '+TARGET)
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TSMC Stock Price '+TARGET)
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(TARGET)
plt.legend()
plt.show()
# plt.savefig('lstm_2330.png')
# Out:
# drop out version,predict by 開盤價
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 25910 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 30436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 25910 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 30436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\f74086250\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 20729 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df=data
df
# Out:
#              日期  股票編號     當日成交量       當日成交金額    開盤價    最高價    最低價    收盤價  \
# 0    2020-01-02  2330  33282120  11224165450  332.5  339.0  332.5  339.0
# 1    2020-01-03  2330  42023268  14295651580  344.0  345.0  335.5  339.5
# 2    2020-01-06  2330  45677057  15210531318  333.0  334.5  332.0  332.0
# 3    2020-01-07  2330  51746181  17053282011  332.5  333.0  326.5  329.5
# 4    2020-01-08  2330  37913748  12484410088  325.0  333.0  325.0  329.5
# ..          ...   ...       ...          ...    ...    ...    ...    ...
# 338  2021-05-28  2330  30720737  18082265480  587.0  592.0  582.0  590.0
# 339  2021-05-31  2330  31557426  18751716595  595.0  597.0  590.0  597.0
# 340  2021-06-01  2330  18405285  10985893229  598.0  599.0  595.0  598.0
# 341  2021-06-02  2330  22416789  13362065937  600.0  600.0  593.0  595.0
# 342  2021-06-03  2330  31703679  18939839664  600.0  600.0  596.0  596.0
#
#      買賣價差    周轉率  ...   昨日融卷   融資變化  融券變化   殖利率    本益比  股價淨值比  大盤融資餘額(百萬)  \
# 0     8.0  17160  ...     31    -11     6  2.36  26.69   5.54  14560.4286
# 1     0.5  20545  ...     37      4    83  2.36  26.73   5.55  14461.7307
# 2    -7.5  22944  ...    120   2552    38  2.41  26.14   5.42  14546.1073
# 3    -2.5  22362  ...    158   -645   -42  2.43  25.94   5.38  14459.4678
# 4     0.0  18228  ...    116    306   -32  2.43  25.94   5.38  14369.2800
# ..    ...    ...  ...    ...    ...   ...   ...    ...    ...         ...
# 338   8.0  31581  ...  26768  40960  3392  1.69  28.30   7.89  23336.5365
# 339   7.0  29798  ...  30160  -4359   248  1.68  28.63   7.98  23404.7805
# 340   1.0  20318  ...  30408  36595  3487  1.67  28.68   8.00  24012.6099
# 341  -3.0  25170  ...  33895 -23766 -2120  1.68  28.54   7.96  24049.8196
# 342   1.0  20749  ...  31775   9890  1551  1.68  28.59   7.97  24595.8470
#
#       大盤融卷量      大盤指數    大盤漲跌
# 0    654584  12100.48  103.34
# 1    652415  12110.43    9.95
# 2    690772  11953.36 -157.07
# 3    691277  11880.32  -73.04
# 4    662743  11817.10  -63.22
# ..      ...       ...     ...
# 338  556327  16870.86  269.25
# 339  551036  17068.43  197.57
# 340  563095  17162.38   93.95
# 341  550856  17165.04    2.66
# 342  559529  17246.16   81.12
#
# [343 rows x 24 columns]

# %%
df.columns=["日期","股票編號","當日成交量","當日成交金額","開盤價","最高價","最低價","收盤價","買賣價差","周轉率",'平均成交價',"當日融資","昨日融資","當日融卷","昨日融卷","融卷變化","融資變化","殖利率","本益比","股價淨值比","大盤融資餘額(百萬)","大盤融卷量","大盤指數","大盤漲跌"]
df=df.drop("股票編號",axis=1)
df.set_index(["日期"], inplace=True)
df.insert(loc=0,column="price",value=df["收盤價"].tolist())
df=df.drop("收盤價",axis=1)

# %%
for column in df:
    print(column,":",end="")
    print(df[column].rolling(10).corr(df['price']).mean(),"& ",end="")
    print(df[column].rolling(20).corr(df['price']).mean(),"& ",end="")
    print(df[column].rolling(30).corr(df['price']).mean(),"& ",end="")
    print(df[column].rolling(50).corr(df['price']).mean())
# Out:
# price :1.0000000000009428 & 1.000000000000125 & 0.9999999999998737 & 0.9999999999999638
# 當日成交量 :-0.146946441727038 & -0.10143826993761623 & -0.06147651626348538 & 0.021043319925088566
# 當日成交金額 :-0.09960496907116104 & -0.038658494039336286 & 0.013561389010311219 & 0.12761692767298963
# 開盤價 :0.8144838435578956 & 0.8968946694830315 & 0.9298011272961704 & 0.9620039197366222
# 最高價 :0.9085407341887464 & 0.9528213565913222 & 0.9664168053606552 & 0.9811801198019717
# 最低價 :0.9084185333440218 & 0.9508660512968987 & 0.9674058152398815 & 0.9815567990064356
# 買賣價差 :0.4405813715962023 & 0.33835866432609646 & 0.27826433634685965 & 0.19242477752802578
# 周轉率 :-0.18312667702205895 & -0.118792506529807 & -0.06716288882310523 & 0.027585165204839727
# 平均成交價 :0.9512847761478067 & 0.9743710780312915 & 0.9823215724070865 & 0.9900569656465411
# 當日融資 :0.19768308504740897 & 0.31012318538865447 & 0.3930026254351712 & 0.5743386205952833
# 昨日融資 :0.16584293987464824 & 0.2830776259152726 & 0.3743512474431672 & 0.5532825226380715
# 當日融卷 :0.07313576218909547 & 0.047082003829404084 & 0.03806297328088043 & 0.02152406069230054
# 昨日融卷 :-0.059883539211761004 & -0.026777521065593477 & -0.00449937230730001 & -0.0025886114331667097
# 融卷變化 :0.051839744338681375 & 0.05091799441427363 & 0.052894053290502174 & 0.07451471775425803
