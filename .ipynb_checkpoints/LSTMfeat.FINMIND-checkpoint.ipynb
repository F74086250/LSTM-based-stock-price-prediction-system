# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests

# %%
TRAIN = 'open'
TARGET = 'close'

# %%
url = "https://api.finmindtrade.com/api/v4/login"
account = {
    "user_id": "F74086250",
    "password": "Aeiou95048",
}
token = requests.post(url, data=account).json()['token']

url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockPrice",
    "data_id": "2330",
    "start_date": "2020-01-01",
    "end_date": "2021-05-31",
    "token":token
}
data = pd.DataFrame(requests.get(url, params=parameter).json()["data"])
data[TRAIN] = data["Trading_money"]/data["Trading_Volume"]
data
# Out:
#            date stock_id  Trading_Volume  Trading_money        open    max  \
# 0    2020-01-02     2330        33282120    11224165450  337.243104  339.0
# 1    2020-01-03     2330        42023268    14295651580  340.184195  345.0
# 2    2020-01-06     2330        45677057    15210531318  333.001562  334.5
# 3    2020-01-07     2330        51746181    17053282011  329.556340  333.0
# 4    2020-01-08     2330        37913748    12484410088  329.284514  333.0
# ..          ...      ...             ...            ...         ...    ...
# 335  2021-05-25     2330        35445350    20525932956  579.086762  584.0
# 336  2021-05-26     2330        19555305    11433686898  584.684662  588.0
# 337  2021-05-27     2330        70061002    40643804852  580.120234  582.0
# 338  2021-05-28     2330        30720737    18082265480  588.601292  592.0
# 339  2021-05-31     2330        31557426    18751716595  594.209318  597.0
#
#        min  close  spread  Trading_turnover
# 0    332.5  339.0     8.0             17160
# 1    335.5  339.5     0.5             20545
# 2    332.0  332.0    -7.5             22944
# 3    326.5  329.5    -2.5             22362
# 4    325.0  329.5     0.0             18228
# ..     ...    ...     ...               ...
# 335  573.0  583.0    15.0             39032
# 336  581.0  585.0     2.0             21034
# 337  573.0  582.0    -3.0             37545
# 338  582.0  590.0     8.0             31581
# 339  590.0  597.0     7.0             29798
#
# [340 rows x 10 columns]

# %%
#切分Test集
test = data[data.date>'2021-02-01']
train = data[data.date<='2021-02-01']
#只要open high
train_set_x = train[TRAIN]
train_set_y = train[TARGET]

# %%
from sklearn.preprocessing import MinMaxScaler 
sc = MinMaxScaler(feature_range = (0, 1))
#需將資料做reshape的動作，使其shape為(資料長度,1) 
train_set_x= train_set_x.values.reshape(-1,1)
training_set_scaled_x = sc.fit_transform(train_set_x)
train_set_y= train_set_y.values.reshape(-1,1)
training_set_scaled_y = sc.fit_transform(train_set_y)

# %%
X_train = [] 
y_train = []
for i in range(10,len(train_set)):
    X_train.append(training_set_scaled_x[i-10:i-1, 0:1]) 
    y_train.append(training_set_scaled_y[i, 0]) 
X_train, y_train = np.array(X_train), np.array(y_train) 
X_train = np.reshape(X_train,(X_train.shape[0], X_train.shape[1], 1))

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout,BatchNormalization

# %%
keras.backend.clear_session()
regressor = Sequential()
regressor.add(LSTM(units = 100, input_shape = (X_train.shape[1], 1)))
regressor.add(Dense(units = 1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = regressor.fit(X_train, y_train, epochs = 150, batch_size = 16)
plt.title('train_loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.plot( history.history["loss"])
# Out:
# Epoch 1/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0670
# Epoch 2/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 3/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 4/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 5/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 6/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 7/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 8/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 9/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 10/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 11/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 12/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 13/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 14/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 15/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 16/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 17/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 18/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 19/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 20/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 21/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 22/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 23/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 24/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 25/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 26/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 27/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 28/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 29/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 30/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 31/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 32/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 33/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 34/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 35/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 36/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 37/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 38/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 39/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 40/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 41/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 42/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 43/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 44/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 45/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 46/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 47/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 48/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 49/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 50/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 51/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 52/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 53/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 54/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 55/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 56/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 57/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 58/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 59/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 60/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 61/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 62/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 63/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 64/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 65/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 66/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 67/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 68/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 69/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 70/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 71/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 72/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 73/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 74/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 75/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 76/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 77/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 78/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 79/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 80/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 81/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 82/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 83/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 84/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 85/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 86/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 87/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 88/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 89/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 90/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 91/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 92/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 93/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 94/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 95/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 96/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 97/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 98/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 99/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 100/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 101/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 102/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 103/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 104/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 105/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 106/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 107/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 108/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 109/150
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 110/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 111/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 112/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 113/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 114/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 115/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 116/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 117/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 118/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 119/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 120/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 121/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 122/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.9846e-04
# Epoch 123/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 124/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 125/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 126/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 127/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 128/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 129/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 130/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 131/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 132/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 133/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 134/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 135/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.6761e-04
# Epoch 136/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.8634e-04
# Epoch 137/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.8277e-04
# Epoch 138/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.4863e-04
# Epoch 139/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.5026e-04
# Epoch 140/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 141/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 142/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 143/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.7437e-04
# Epoch 144/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.9828e-04
# Epoch 145/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.5643e-04
# Epoch 146/150
# 16/16 [==============================] - 0s 3ms/step - loss: 9.4890e-04
# Epoch 147/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.4734e-04
# Epoch 148/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.5565e-04
# Epoch 149/150
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 150/150
# 16/16 [==============================] - 0s 2ms/step - loss: 9.0258e-04

# %%
dataset_total = pd.concat((train[TRAIN], test[TARGET]), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test) - 10:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(10, len(inputs)):
    X_test.append(inputs[i-10:i-1, 0])
X_test = np.array(X_test)
#print(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
#print(X_test)
predicted_stock_price = regressor.predict(X_test)
print(predicted_stock_price)
#使用sc的 inverse_transform將股價轉為歸一化前
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000203CD4BD040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[0.8359918 ]
#  [0.83307993]
#  [0.87676495]
#  [0.9028285 ]
#  [0.89945465]
#  [0.8950401 ]
#  [0.93666816]
#  [0.962061  ]
#  [0.9531015 ]
#  [0.9371217 ]
#  [0.91983575]
#  [0.8931462 ]
#  [0.89617187]
#  [0.8673871 ]
#  [0.8509602 ]
#  [0.86691976]
#  [0.8532341 ]
#  [0.8373488 ]
#  [0.82642263]
#  [0.8196899 ]
#  [0.82090634]
#  [0.83881086]
#  [0.8569914 ]
#  [0.858217  ]
#  [0.85525256]
#  [0.8414678 ]
#  [0.83091927]
#  [0.8142117 ]
#  [0.80935836]
#  [0.81300265]
#  [0.79232556]
#  [0.7751799 ]
#  [0.7900345 ]
#  [0.81719255]
#  [0.8271784 ]
#  [0.81043714]
#  [0.8162205 ]
#  [0.8371398 ]
#  [0.84936446]
#  [0.8548518 ]
#  [0.85082626]
#  [0.84031487]
#  [0.8354771 ]
#  [0.84578377]
#  [0.86415   ]
#  [0.8603416 ]
#  [0.8420954 ]
#  [0.8304674 ]
#  [0.81566966]
#  [0.8081861 ]
#  [0.8225501 ]
#  [0.8449985 ]
#  [0.8544931 ]
#  [0.8418086 ]
#  [0.827701  ]
#  [0.8069708 ]
#  [0.80197126]
#  [0.79763305]
#  [0.7985573 ]
#  [0.81615514]
#  [0.813773  ]
#  [0.7815811 ]
#  [0.7460083 ]
#  [0.71539956]
#  [0.71886927]
#  [0.71978384]
#  [0.7480248 ]
#  [0.759728  ]
#  [0.7570674 ]
#  [0.7590035 ]
#  [0.75486195]
#  [0.77142465]
#  [0.7875193 ]
#  [0.7889777 ]]

# %%
plt.plot(test[TARGET].values, color = 'black', label = 'Real TSMC Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TSMC Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
#plt.savefig('lstm_2330.png')
